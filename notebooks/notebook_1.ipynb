# %%
import nltk  # Bibliothèque NLP (traitement du langage naturel)
import matplotlib.pyplot as plt
import numpy as np
import re  # Expressions régulières pour le nettoyage de texte
import string  # Manipulation de la ponctuation (ex : suppression des signes de ponctuation)

from nltk.corpus import stopwords, twitter_samples  # Liste des mots vides (ex : "le", "de", "the") à retirer
from nltk.stem import PorterStemmer  # Algorithme de stemming pour réduire les mots à leur racine
from nltk.stem import WordNetLemmatizer  # Lemmatisation : transformation des mots à leur forme canonique
from nltk.tokenize import TweetTokenizer  # Tokenizer adapté aux tweets (hashtags, mentions, emojis)
from sklearn.feature_extraction.text import CountVectorizer

nltk.download("wordnet")  # Téléchargement de WordNet, nécessaire pour la lemmatisation
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gpres\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gpres\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\gpres\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
pos_tweets = twitter_samples.strings('positive_tweets.json')
neg_tweets = twitter_samples.strings('negative_tweets.json')

# %%
#Fussion des positifs et negatif
tweets = pos_tweets + neg_tweets

# %%
print("nombre de tweets:", len(tweets))
print("nombre de tweets positifs : ", len(pos_tweets))
print("nombre de tweets negatifs : ", len(neg_tweets))
# Out:
# nombre de tweets: 10000
# nombre de tweets positifs :  5000
# nombre de tweets negatifs :  5000

# %%
#Illustration de la segmentation
tweet = pos_tweets[1510]

tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
tweet_tokens = tokenizer.tokenize(tweet)

# %%
print("Tweet")
print(tweet)
# Out:
# Tweet
# @TheBookwormBaby Thank you! that's very kind.  I just finished working on more Little Explorers books btw which will be out next year.. :)

# %%
print("Tweet segement")
print(tweet_tokens)
# Out:
# Tweet segement
# ['thank', 'you', '!', "that's", 'very', 'kind', '.', 'i', 'just', 'finished', 'working', 'on', 'more', 'little', 'explorers', 'books', 'btw', 'which', 'will', 'be', 'out', 'next', 'year', '..', ':)']

# %%
#Suppression des stopwords et ponctuation
tweet_clean = []

stopwords_english = stopwords.words("english")

for word in tweet_tokens:
    if (word not in stopwords_english and 
        word not in string.punctuation):
        tweet_clean.append(word)
        
print (tweet_clean)
# Out:
# ['thank', "that's", 'kind', 'finished', 'working', 'little', 'explorers', 'books', 'btw', 'next', 'year', '..', ':)']

# %%
lemmatizer = WordNetLemmatizer()
tweet_clean_and_lem = [lemmatizer.lemmatize(word) for word in tweet_clean]

print(tweet_clean_and_lem)
# Out:
# ['thank', "that's", 'kind', 'finished', 'working', 'little', 'explorer', 'book', 'btw', 'next', 'year', '..', ':)']

# %%
#Fonction de preprocessing
def traiter_tweet (tweet):
    """
    Input:
        tweet
    Output:
        une liste des mots du tweet après pré-traitement
    """
    
    lemmatizer = WordNetLemmatizer()
    stopwords_english = stopwords.words("english")
    
    #suppression du #
    tweet = re.sub(r'#', '', tweet)
    
    #Segmentation
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
    
    tweet_clen = []
    
    for word in tweet_tokens :
        if (word not in stopwords_english and
            word not in string.punctuation):
            
            lem_word = lemmatizer.lemmatize(word)
            tweet_clean.append(lem_word)
            
    return tweet_clean

# %%
def freq_words (tweets, labelArray):
    """ compte de fréquences.
    Input:
        tweets
        labelArray: un tableau avec le label pour chaque tweet (1/0)
    Output:
        freqs: un dictionnaire de paires (mot, label) et leurs fréquences
    """
    
    labelList = np.squeeze(labelArray).tolist()
    freqs = {}
    for y, tweet in zip(labelList, tweets):
        for word in traiter_tweet(tweet):
            pair = (word, y)
            if pair in freqs:
                freqs[pair] += 1
            else:
                freqs[pair] = 1
    return freqs

# %%
# Création des labels correspondants
labels_pos = [1]*len(pos_tweets)
labels_neg = [0]*len(neg_tweets)

# Concaténation des tweets et des labels
labels = labels_pos + labels_neg

# %%
#Extraire les fréquences
freqs = freq_words(tweets, labels)

# %%
freqs
# Out:
# {('thank', 1): 589522,
#  ("that's", 1): 162098,
#  ('kind', 1): 71148,
#  ('finished', 1): 40395,
#  ('working', 1): 97705,
#  ('little', 1): 89334,
#  ('explorers', 1): 5000,
#  ('books', 1): 5000,
#  ('btw', 1): 29237,
#  ('next', 1): 124284,
#  ('year', 1): 120851,
#  ('..', 1): 314813,
#  (':)', 1): 9280270,
#  ('followfriday', 1): 114897,
#  ('top', 1): 136418,
#  ('engaged', 1): 35433,
#  ('member', 1): 55341,
#  ('community', 1): 126275,
#  ('week', 1): 249909,
#  ('hey', 1): 179844,
#  ('james', 1): 23769,
#  ('odd', 1): 4999,
#  (':/', 1): 18040,
#  ('please', 1): 249365,
#  ('call', 1): 70099,
#  ('contact', 1): 17304,
#  ('centre', 1): 5996,
#  ('02392441234', 1): 4999,
#  ('able', 1): 22355,
#  ('assist', 1): 4999,
#  ('many', 1): 88061,
#  ('thanks', 1): 993760,
#  ('listen', 1): 34720,
#  ('last', 1): 121329,
#  ('night', 1): 180428,
#  ('bleed', 1): 8155,
#  ('amazing', 1): 127153,
#  ('track', 1): 20497,
#  ('scotland', 1): 9856,
#  ('congrats', 1): 49029,
#  ('yeaaah', 1): 4996,
#  ('yipppy', 1): 4996,
#  ('accnt', 1): 9885,
#  ('verified', 1): 4996,
#  ('rqst', 1): 4996,
#  ('succeed', 1): 4996,
#  ('got', 1): 168606,
#  ('blue', 1): 26614,
#  ('tick', 1): 4996,
#  ('mark', 1): 4996,
#  ('fb', 1): 16713,
#  ('profile', 1): 9108,
#  ('15', 1): 14575,
#  ('day', 1): 594904,
#  ('one', 1): 274945,
#  ('irresistible', 1): 6943,
#  ('flipkartfashionfriday', 1): 52468,
#  ('http://t.co/EbZ0L2VENM', 1): 4995,
#  ('like', 1): 577597,
#  ('keep', 1): 148418,
#  ('lovely', 1): 152304,
#  ('customer', 1): 10541,
#  ('waiting', 1): 79765,
#  ('long', 1): 82370,
#  ('hope', 1): 328677,
#  ('enjoy', 1): 146832,
#  ('happy', 1): 460502,
#  ('friday', 1): 277307,
#  ('lwwf', 1): 4994,
#  ('https://t.co/smyYriipxI', 1): 4994,
#  ('second', 1): 23772,
#  ('thought', 1): 70699,
#  ('’', 1): 55308,
#  ('enough', 1): 53458,
#  ('time', 1): 315170,
#  ('dd', 1): 4993,
#  ('new', 1): 360391,
#  ('short', 1): 20148,
#  ('entering', 1): 4993,
#  ('system', 1): 7949,
#  ('sheep', 1): 4993,
#  ('must', 1): 40836,
#  ('buying', 1): 4993,
#  ('jgh', 1): 17125,
#  ('go', 1): 231777,
#  ('bayan', 1): 4992,
#  (':D', 1): 1628725,
#  ('bye', 1): 18863,
#  ('act', 1): 24003,
#  ('mischievousness', 1): 4991,
#  ('calling', 1): 16586,
#  ('etl', 1): 4991,
#  ('layer', 1): 4991,
#  ('in-house', 1): 4991,
#  ('warehousing', 1): 4991,
#  ('app', 1): 32778,
#  ('katamari', 1): 4991,
#  ('well', 1): 201367,
#  ('…', 1): 98687,
#  ('name', 1): 39582,
#  ('implies', 1): 4991,
#  (':p', 1): 335457,
#  ('influencers', 1): 35987,
#  ('love', 1): 861251,
#  ('big', 1): 86121,
#  ('...', 1): 713701,
#  ('juicy', 1): 10315,
#  ('selfies', 1): 19739,
#  ('http://t.co/QVzjgd1uFo', 1): 4989,
#  ('http://t.co/oWBL11eQRY', 1): 4989,
#  ('follow', 1): 1008616,
#  ('http://t.co/RCvcYYO0Iq', 1): 258925,
#  ('u', 1): 1033606,
#  ('back', 1): 511368,
#  ('perfect', 1): 54165,
#  ('already', 1): 57223,
#  ('know', 1): 414519,
#  ("what's", 1): 39290,
#  ('great', 1): 425791,
#  ('opportunity', 1): 57566,
#  ('junior', 1): 8494,
#  ('triathletes', 1): 4986,
#  ('aged', 1): 4986,
#  ('12', 1): 16265,
#  ('13', 1): 13834,
#  ('gatorade', 1): 4986,
#  ('series', 1): 11372,
#  ('get', 1): 430280,
#  ('entry', 1): 13849,
#  ('http://t.co/of3DyOzML0', 1): 4986,
#  ('laying', 1): 8473,
#  ('greeting', 1): 12464,
#  ('card', 1): 21279,
#  ('range', 1): 8658,
#  ('print', 1): 6863,
#  ('today', 1): 296740,
#  ('job', 1): 116380,
#  (':-)', 1): 1716793,
#  ("friend's", 1): 13503,
#  ('lunch', 1): 11939,
#  ('yummm', 1): 4984,
#  ('nostalgia', 1): 4984,
#  ('tb', 1): 5818,
#  ('ku', 1): 4984,
#  ('id', 1): 21896,
#  ('conflict', 1): 4983,
#  ('help', 1): 101507,
#  ("here's", 1): 63886,
#  ('screenshot', 1): 4983,
#  ('hi', 1): 499459,
#  ('liv', 1): 6228,
#  ('hello', 1): 153869,
#  ('need', 1): 165168,
#  ('something', 1): 72181,
#  ('fm', 1): 6206,
#  ('twitter', 1): 84735,
#  ('—', 1): 75255,
#  ('sure', 1): 117056,
#  ('thing', 1): 167848,
#  ('dm', 1): 104549,
#  ('x', 1): 163207,
#  ('http://t.co/W6Dy130BV7', 1): 4981,
#  ('follower', 1): 206018,
#  ('heard', 1): 27300,
#  ('four', 1): 14418,
#  ('season', 1): 17392,
#  ('pretty', 1): 55060,
#  ('dope', 1): 9008,
#  ('penthouse', 1): 4979,
#  ('obvs', 1): 4979,
#  ('gobigorgohome', 1): 4979,
#  ('fun', 1): 158707,
#  ("y'all", 1): 14919,
#  ('yeah', 1): 104824,
#  ('suppose', 1): 21262,
#  ('lol', 1): 160761,
#  ('chat', 1): 28761,
#  ('bit', 1): 54672,
#  ('youth', 1): 48377,
#  ('💅🏽', 1): 4976,
#  ('💋', 1): 6828,
#  ('seen', 1): 23325,
#  ('rest', 1): 35519,
#  ('quickly', 1): 9963,
#  ('bed', 1): 34213,
#  ('music', 1): 42470,
#  ('fix', 1): 13599,
#  ('dream', 1): 50422,
#  ('spiritual', 1): 4973,
#  ('ritual', 1): 4973,
#  ('festival', 1): 18728,
#  ('népal', 1): 4973,
#  ('beginning', 1): 10957,
#  ('line-up', 1): 17770,
#  ('left', 1): 35754,
#  ('see', 1): 439367,
#  ('http://t.co/QMNz62OEuc', 1): 4973,
#  ('sarah', 1): 14078,
#  ('send', 1): 27359,
#  ('email', 1): 63338,
#  ('bitsy@bitdefender.com', 1): 4972,
#  ('asap', 1): 14449,
#  ('lols', 1): 4971,
#  ('kik', 1): 45797,
#  ('hatessuce', 1): 4970,
#  ('32429', 1): 4970,
#  ('kikme', 1): 4970,
#  ('lgbt', 1): 6984,
#  ('tinder', 1): 4970,
#  ('nsfw', 1): 4970,
#  ('akua', 1): 4970,
#  ('cumshot', 1): 4970,
#  ('http://t.co/TnHJD36yzf', 1): 4970,
#  ('come', 1): 152693,
#  ('house', 1): 15832,
#  ('nsn_supplements', 1): 4968,
#  ('effective', 1): 4968,
#  ('press', 1): 4968,
#  ('release', 1): 27204,
#  ('distribution', 1): 4968,
#  ('result', 1): 8847,
#  ('link', 1): 35438,
#  ('removed', 1): 8238,
#  ('pressrelease', 1): 4968,
#  ('newsdistribution', 1): 4968,
#  ('bam', 1): 136766,
#  ('bestfriend', 1): 147628,
#  ('lot', 1): 247622,
#  ('warsaw', 1): 136766,
#  ('<3', 1): 383780,
#  ('x46', 1): 4967,
#  ('everyone', 1): 136855,
#  ('watch', 1): 52889,
#  ('documentary', 1): 4966,
#  ('earthling', 1): 5404,
#  ('youtube', 1): 22092,
#  ('support', 1): 80172,
#  ('buuut', 1): 4963,
#  ('oh', 1): 144921,
#  ('looking', 1): 149176,
#  ('forward', 1): 69220,
#  ('visiting', 1): 10650,
#  ('letsgetmessy', 1): 4962,
#  ('jo', 1): 4962,
#  ('make', 1): 191432,
#  ('feel', 1): 72505,
#  ('better', 1): 117734,
#  ('never', 1): 93889,
#  ('anyone', 1): 28283,
#  ('kpop', 1): 4961,
#  ('flesh', 1): 4961,
#  ('good', 1): 570550,
#  ('girl', 1): 116585,
#  ('best', 1): 142871,
#  ('wish', 1): 55119,
#  ('reason', 1): 32143,
#  ('epic', 1): 5450,
#  ('soundtrack', 1): 4959,
#  ('shout', 1): 27536,
#  ('added', 1): 31305,
#  ('video', 1): 91124,
#  ('playlist', 1): 21249,
#  ('http://t.co/yzpfsMxUq0', 1): 4957,
#  ('im', 1): 141327,
#  ('twitch', 1): 20332,
#  ('going', 1): 173109,
#  ('league', 1): 21787,
#  ('1', 1): 194380,
#  ('4', 1): 69913,
#  ('would', 1): 226145,
#  ('dear', 1): 48772,
#  ('jordan', 1): 4956,
#  ('okay', 1): 87517,
#  ('fake', 1): 4954,
#  ('gameplays', 1): 5327,
#  (';)', 1): 70065,
#  ('haha', 1): 134463,
#  ('kidding', 1): 15549,
#  ('stuff', 1): 35365,
#  ('exactly', 1): 14906,
#  ('product', 1): 25895,
#  ('line', 1): 16412,
#  ('etsy', 1): 4952,
#  ('shop', 1): 27247,
#  ('check', 1): 119203,
#  ('http://t.co/h8exCTLQxg', 1): 4952,
#  ('boxroomcrafts', 1): 4952,
#  ('vacation', 1): 18637,
#  ('rechargeable', 1): 4950,
#  ('normally', 1): 7453,
#  ('charger', 1): 9366,
#  ('buy', 1): 25205,
#  ('asleep', 1): 25588,
#  ('talk', 1): 67605,
#  ('sooo', 1): 16564,
#  ('someone', 1): 87159,
#  ('text', 1): 36602,
#  ('yes', 1): 202661,
#  ('bet', 1): 19585,
#  ('fit', 1): 7838,
#  ('hearing', 1): 5081,
#  ('speech', 1): 4947,
#  ('pity', 1): 9474,
#  ('green', 1): 7462,
#  ('garden', 1): 15584,
#  ('midnight', 1): 4946,
#  ('sun', 1): 19004,
#  ('beautiful', 1): 142149,
#  ('canal', 1): 4946,
#  ('dasvidaniya', 1): 4946,
#  ('till', 1): 52854,
#  ('visit', 1): 70474,
#  ('scouting', 1): 4945,
#  ('sg', 1): 4945,
#  ('future', 1): 31888,
#  ('wlan', 1): 4945,
#  ('pro', 1): 13049,
#  ('conference', 1): 4945,
#  ('asia', 1): 4945,
#  ('change', 1): 49628,
#  ('lollipop', 1): 4944,
#  ('🍭', 1): 4944,
#  ('nez', 1): 4943,
#  ('agnezmo', 1): 4943,
#  ('https://t.co/cGViMHSINz', 1): 4943,
#  ('oley', 1): 4941,
#  ('mama', 1): 4940,
#  ('stand', 1): 13321,
#  ('stronger', 1): 4940,
#  ('god', 1): 46785,
#  ('misty', 1): 4938,
#  ('baby', 1): 59304,
#  ('cute', 1): 69743,
#  ('http://t.co/HnbinH35ES', 1): 4937,
#  ('woohoo', 1): 11057,
#  ("can't", 1): 91640,
#  ('wait', 1): 94475,
#  ('signed', 1): 11159,
#  ('yet', 1): 34916,
#  ('still', 1): 117933,
#  ('thinking', 1): 22493,
#  ('mka', 1): 15884,
#  ('liam', 1): 22096,
#  ('access', 1): 13617,
#  ('welcome', 1): 168522,
#  ('stats', 1): 148880,
#  ('arrived', 1): 160822,
#  ('unfollowers', 1): 148880,
#  ('via', 1): 203676,
#  ('http://t.co/p6K6SiH58a', 1): 4933,
#  ('surprised', 1): 9727,
#  ('figure', 1): 15287,
#  ('happybirthdayemilybett', 1): 4930,
#  ('wishing', 1): 37831,
#  ('sweet', 1): 45739,
#  ('talented', 1): 17260,
#  ('https://t.co/humtC1tr3I', 1): 4930,
#  ('2', 1): 131890,
#  ('plan', 1): 46949,
#  ('drain', 1): 4929,
#  ('gotta', 1): 14357,
#  ('timezones', 1): 4928,
#  ('parent', 1): 16071,
#  ('proud', 1): 35927,
#  ('least', 1): 54455,
#  ('maybe', 1): 60381,
#  ('sometimes', 1): 27062,
#  ('grade', 1): 15509,
#  ('al', 1): 13631,
#  ('http://t.co/bJjeGIOOGU', 1): 4927,
#  ('grande', 1): 11334,
#  ('https://t.co/gsaaxNpR8u', 1): 4926,
#  ('manila_bro', 1): 5020,
#  ('chosen', 1): 4925,
#  ('http://t.co/lKXZWXN1fb', 1): 4925,
#  ('let', 1): 211492,
#  ('around', 1): 44410,
#  ('side', 1): 45575,
#  ('world', 1): 58762,
#  ('eh', 1): 9097,
#  ('take', 1): 97132,
#  ('care', 1): 35720,
#  ('finally', 1): 50151,
#  ('fucking', 1): 28913,
#  ('weekend', 1): 197032,
#  ('real', 1): 50062,
#  ('x45', 1): 4919,
#  ('joined', 1): 24189,
#  ('hushedcallwithfraydoe', 1): 4918,
#  ('gift', 1): 19331,
#  ('http://t.co/VaLVe8omdT', 1): 4918,
#  ('yeahhh', 1): 4917,
#  ('hushedpinwithsammy', 1): 9713,
#  ('event', 1): 25503,
#  ('might', 1): 69335,
#  ('luv', 1): 17731,
#  ('http://t.co/kGfgawdHy9', 1): 4915,
#  ('really', 1): 202241,
#  ('appreciate', 1): 50569,
#  ('share', 1): 59884,
#  ('https://t.co/MhK3B3wOpQ', 1): 4914,
#  ('wow', 1): 37294,
#  ('tom', 1): 16165,
#  ('https://t.co/wx7yRrE7sV', 1): 4911,
#  ('http://t.co/HVVPhSYakA', 1): 4910,
#  ('3', 1): 84330,
#  ('gym', 1): 7755,
#  ('monday', 1): 22577,
#  ('invite', 1): 39756,
#  ('join', 1): 42749,
#  ('scope', 1): 19099,
#  ('influencer', 1): 19099,
#  ('http://t.co/rZgZtQ2fJT', 1): 8244,
#  ('friend', 1): 130969,
#  ('nude', 1): 5478,
#  ('sleep', 1): 101277,
#  ('http://t.co/RB8pMNgMEo', 1): 4902,
#  ('birthday', 1): 166746,
#  ('want', 1): 178162,
#  ('t-shirt', 1): 8808,
#  ('cool', 1): 99215,
#  ('haw', 1): 4899,
#  ('phela', 1): 4899,
#  ('mom', 1): 32192,
#  ('obviously', 1): 5583,
#  ('prince', 1): 4898,
#  ('charming', 1): 4898,
#  ('stage', 1): 8095,
#  ('https://t.co/OnVFhzt5fZ', 1): 4898,
#  ('luck', 1): 79906,
#  ('http://t.co/XzsOGaC4zK', 1): 4896,
#  ('tyler', 1): 4948,
#  ('hipster', 1): 4894,
#  ('glass', 1): 11018,
#  ('marty', 1): 8105,
#  ('glad', 1): 110667,
#  ('joining', 1): 10136,
#  ('done', 1): 116887,
#  ('afternoon', 1): 26526,
#  ('read', 1): 53780,
#  ('kahfi', 1): 4890,
#  ('finish', 1): 9048,
#  ('ohmyg', 1): 4889,
#  ('yaya', 1): 10260,
#  ('dub', 1): 4889,
#  ('stalk', 1): 4889,
#  ('ig', 1): 10964,
#  ('gondooo', 1): 4889,
#  ('moo', 1): 6569,
#  ('tologooo', 1): 4889,
#  ('become', 1): 18720,
#  ('detail', 1): 18301,
#  ('http://t.co/ipJ2yOiGet', 1): 10635,
#  ('zzz', 1): 4886,
#  ('xx', 1): 111709,
#  ('physiotherapy', 1): 4885,
#  ('hashtag', 1): 11853,
#  ('custom', 1): 4885,
#  ('💪', 1): 4884,
#  ('monica', 1): 4884,
#  ('miss', 1): 41977,
#  ('sound', 1): 50696,
#  ('morning', 1): 208888,
#  ('x43', 1): 4882,
#  ('definitely', 1): 68724,
#  ('try', 1): 55543,
#  ('tonight', 1): 46941,
#  ('took', 1): 19139,
#  ('advice', 1): 21291,
#  ('treviso', 1): 4881,
#  ('concert', 1): 77559,
#  ('city', 1): 88275,
#  ('country', 1): 72604,
#  ('start', 1): 141924,
#  ('fine', 1): 24211,
#  ('gorgeous', 1): 33471,
#  ('xo', 1): 9045,
#  ('https://t.co/JmpkZP2DaI', 1): 4878,
#  ('oven', 1): 6363,
#  ('roasted', 1): 4877,
#  ('garlic', 1): 4877,
#  ('olive', 1): 4877,
#  ('oil', 1): 14496,
#  ('dried', 1): 9754,
#  ('tomato', 1): 4877,
#  ('basil', 1): 4877,
#  ('century', 1): 4877,
#  ('tuna', 1): 4877,
#  ('https://t.co/EsCc9QhLob', 1): 4877,
#  ('right', 1): 110253,
#  ('atchya', 1): 4876,
#  ('even', 1): 72493,
#  ('almost', 1): 27963,
#  ('https://t.co/rolE3ZCL97', 1): 4874,
#  ('chance', 1): 10239,
#  ('cheer', 1): 55795,
#  ('po', 1): 14087,
#  ('ice', 1): 19865,
#  ('cream', 1): 22982,
#  ('agree', 1): 34443,
#  ('100', 1): 19697,
#  ('hehehehe', 1): 7259,
#  ('thats', 1): 31021,
#  ('point', 1): 32328,
#  ('stay', 1): 60367,
#  ('home', 1): 59145,
#  ('soon', 1): 104599,
#  ('promise', 1): 14072,
#  ('web', 1): 14526,
#  ('whatsapp', 1): 9467,
#  ('volta', 1): 4863,
#  ('funcionar', 1): 4863,
#  ('com', 1): 6622,
#  ('iphone', 1): 17122,
#  ('jailbroken', 1): 4863,
#  ('watching', 1): 35277,
#  ('later', 1): 38141,
#  ('34', 1): 8615,
#  ('min', 1): 17475,
#  ('leia', 1): 4862,
#  ('appears', 1): 6143,
#  ('hologram', 1): 4862,
#  ('r2d2', 1): 4862,
#  ('w', 1): 57350,
#  ('message', 1): 25142,
#  ('obi', 1): 4862,
#  ('wan', 1): 6015,
#  ('sits', 1): 8496,
#  ('luke', 1): 14663,
#  ('inter', 1): 4861,
#  ('ucl', 1): 4861,
#  ('arsenal', 1): 6079,
#  ('small', 1): 10364,
#  ('team', 1): 70550,
#  ('passing', 1): 4860,
#  ('🚂', 1): 4860,
#  ('dewsbury', 1): 9720,
#  ('railway', 1): 4860,
#  ('station', 1): 16388,
#  ('dew', 1): 4860,
#  ('west', 1): 5750,
#  ('yorkshire', 1): 9580,
#  ('https://t.co/DvBssHbrfx', 1): 4860,
#  ('430', 1): 4859,
#  ('smh', 1): 8212,
#  ('9:25', 1): 4858,
#  ('live', 1): 50518,
#  ('strange', 1): 12871,
#  ('imagine', 1): 14509,
#  ('megan', 1): 4858,
#  ('masaantoday', 1): 20896,
#  ('a4', 1): 8477,
#  ('shweta', 1): 4857,
#  ('tripathi', 1): 4857,
#  ('5', 1): 49637,
#  ('20', 1): 17506,
#  ('kurta', 1): 8476,
#  ('half', 1): 21826,
#  ('number', 1): 37895,
#  ('wsalelove', 1): 46452,
#  ('ah', 1): 40592,
#  ('larry', 1): 11598,
#  ('https://t.co/8XhjJb4jtH', 1): 4855,
#  ('anyway', 1): 42114,
#  ('kinda', 1): 34580,
#  ('goood', 1): 6652,
#  ('life', 1): 109333,
#  ('enn', 1): 4852,
#  ('https://t.co/GLoCEIjGQQ', 1): 4852,
#  ('surely', 1): 7571,
#  ('could', 1): 88640,
#  ('warmup', 1): 4851,
#  ('coming', 1): 45661,
#  ('15th', 1): 7568,
#  ('bath', 1): 18266,
#  ('dum', 1): 9700,
#  ('andar', 1): 4850,
#  ('ram', 1): 4850,
#  ('sampath', 1): 4850,
#  ('sona', 1): 4850,
#  ('mohapatra', 1): 4850,
#  ('samantha', 1): 4850,
#  ('edward', 1): 4850,
#  ('mein', 1): 4850,
#  ('tulane', 1): 4850,
#  ('razi', 1): 9700,
#  ('wah', 1): 8707,
#  ('josh', 1): 4850,
#  ('http://t.co/ul8MARDfhm', 1): 4850,
#  ('always', 1): 153810,
#  ('smile', 1): 102702,
#  ('picture', 1): 32071,
#  ('16.20', 1): 4847,
#  ('timing', 1): 9284,
#  ('giveitup', 1): 4844,
#  ('given', 1): 11555,
#  ('gas', 1): 4844,
#  ('subsidy', 1): 4844,
#  ('initiative', 1): 4844,
#  ('proposed', 1): 4844,
#  ('feeling', 1): 38224,
#  ('delighted', 1): 10966,
#  ('missed', 1): 8559,
#  ('yesterday', 1): 15461,
#  ('x42', 1): 4842,
#  ('lmaoo', 1): 8186,
#  ('song', 1): 53282,
#  ('ever', 1): 57640,
#  ('shall', 1): 13895,
#  ('throwback', 1): 12856,
#  ('outlying', 1): 4840,
#  ('island', 1): 7772,
#  ('cheung', 1): 4840,
#  ('chau', 1): 4840,
#  ('mui', 1): 4840,
#  ('wo', 1): 4840,
#  ('totally', 1): 21015,
#  ('different', 1): 20250,
#  ('kfckitchentours', 1): 7058,
#  ('kitchen', 1): 10938,
#  ('clean', 1): 4839,
#  ('amazed', 1): 4839,
#  ('cusp', 1): 4837,
#  ('testing', 1): 7239,
#  ('water', 1): 21232,
#  ('rewarding', 1): 4837,
#  ('arummzz', 1): 5934,
#  ("let's", 1): 48086,
#  ('drive', 1): 15859,
#  ('traveling', 1): 14956,
#  ('traveler', 1): 10738,
#  ('yogyakarta', 1): 10738,
#  ('jeep', 1): 10738,
#  ('indonesia', 1): 11423,
#  ('instamood', 1): 10738,
#  ('https://t.co/s7y4Ys5JeU', 1): 9639,
#  ('wanna', 1): 77814,
#  ('skype', 1): 12906,
#  ('may', 1): 56055,
#  ('look', 1): 199189,
#  ('nice', 1): 215505,
#  ('friendly', 1): 5512,
#  ('pretend', 1): 6438,
#  ('film', 1): 15872,
#  ('congratulation', 1): 28344,
#  ('winner', 1): 12312,
#  ('cheesydelights', 1): 4830,
#  ('contest', 1): 16293,
#  ('address', 1): 30102,
#  ('guy', 1): 153571,
#  ('https://t.co/DLDKLpeTAb', 1): 4829,
#  ('seeing', 1): 44439,
#  ('marketing', 1): 7795,
#  ('24/7', 1): 4826,
#  ('http://t.co/O5fjR7oEqk', 1): 4826,
#  ('regret', 1): 14159,
#  ('14', 1): 4825,
#  ('hour', 1): 81064,
#  ('leave', 1): 27623,
#  ('without', 1): 30315,
#  ('delay', 1): 5148,
#  ('actually', 1): 39084,
#  ('easy', 1): 22525,
#  ('guess', 1): 27694,
#  ('train', 1): 16080,
#  ('wd', 1): 4824,
#  ('shifting', 1): 4824,
#  ('engine', 1): 4824,
#  ('etc', 1): 6289,
#  ('sunburn', 1): 4823,
#  ('peeling', 1): 4823,
#  ('blog', 1): 78909,
#  ('http://t.co/UzOAqroWKx', 1): 30857,
#  ('huge', 1): 29778,
#  ('warm', 1): 15759,
#  ('☆', 1): 11518,
#  ('complete', 1): 16050,
#  ('triangle', 1): 8756,
#  ('northern', 1): 4818,
#  ('ireland', 1): 6480,
#  ('sight', 1): 4818,
#  ('http://t.co/6prugvmOuC', 1): 4815,
#  ('smthng', 1): 9628,
#  ('fr', 1): 13213,
#  ('hug', 1): 31727,
#  ('xoxo', 1): 10165,
#  ('uu', 1): 4814,
#  ('jaann', 1): 4814,
#  ('topnewfollowers', 1): 7179,
#  ('connect', 1): 20242,
#  ('wonderful', 1): 50915,
#  ('made', 1): 109029,
#  ('fluffy', 1): 4811,
#  ('inside', 1): 20269,
#  ('pirouette', 1): 4811,
#  ('moose', 1): 4811,
#  ('trip', 1): 37774,
#  ('philly', 1): 4810,
#  ('december', 1): 10226,
#  ('dude', 1): 20471,
#  ('x41', 1): 4809,
#  ('question', 1): 47357,
#  ('flawed', 1): 4808,
#  ('pain', 1): 23842,
#  ('negate', 1): 4808,
#  ('strength', 1): 10192,
#  ('https://t.co/77TbkS2Djw', 1): 4808,
#  ('went', 1): 26453,
#  ('solo', 1): 16814,
#  ('move', 1): 23247,
#  ('fav', 1): 30808,
#  ('nirvana', 1): 4806,
#  ('smell', 1): 6197,
#  ('teen', 1): 9965,
#  ('spirit', 1): 5517,
#  ('rip', 1): 10845,
#  ('amy', 1): 10825,
#  ('winehouse', 1): 4806,
#  ('couple', 1): 14861,
#  ('tomhiddleston', 1): 4803,
#  ('elizabetholsen', 1): 4803,
#  ('yaytheylookgreat', 1): 4803,
#  ('goodnight', 1): 54602,
#  ('vid', 1): 22248,
#  ('wake', 1): 20141,
#  ('gonna', 1): 47428,
#  ('shoot', 1): 10066,
#  ('http://t.co/s3e2dmpt24', 1): 4801,
#  ('itty', 1): 5835,
#  ('bitty', 1): 5835,
#  ('teenie', 1): 5835,
#  ('bikini', 1): 7242,
#  ('http://t.co/A2oxW0ZI3g', 1): 4799,
#  ('http://t.co/jn7KSfHwRc', 1): 4799,
#  ('http://t.co/czdow1i44W', 1): 4798,
#  ('much', 1): 223547,
#  ('4th', 1): 11141,
#  ('together', 1): 20146,
#  ('ending', 1): 5454,
#  ('xfiles', 1): 4797,
#  ('content', 1): 9564,
#  ('rain', 1): 45395,
#  ('fabulous', 1): 16125,
#  ('fantastic', 1): 34893,
#  ('work', 1): 178411,
#  ('♡', 1): 51696,
#  ('jb', 1): 4792,
#  ('forever', 1): 16085,
#  ('belieber', 1): 8962,
#  ('hear', 1): 62783,
#  ('nighty', 1): 4788,
#  ('bug', 1): 8213,
#  ('bite', 1): 4788,
#  ('bracelet', 1): 8064,
#  ('idea', 1): 68094,
#  ('foundry', 1): 4786,
#  ('game', 1): 69822,
#  ('sense', 1): 23013,
#  ('pic', 1): 71783,
#  ('effing', 1): 4784,
#  ('phone', 1): 46077,
#  ('woot', 1): 8318,
#  ('derek', 1): 4783,
#  ('using', 1): 24106,
#  ('parkshare', 1): 4783,
#  ('gloucestershire', 1): 4783,
#  ('http://t.co/qIF9AyAlkc', 1): 4783,
#  ('aaaahhh', 1): 4782,
#  ('man', 1): 48243,
#  ('traffic', 1): 6454,
#  ('stress', 1): 14658,
#  ('reliever', 1): 4782,
#  ("how're", 1): 4780,
#  ('arbeloa', 1): 4779,
#  ('turning', 1): 12241,
#  ('17', 1): 9636,
#  ('omg', 1): 38395,
#  ('difference', 1): 6935,
#  ('say', 1): 101091,
#  ('europe', 1): 4777,
#  ('rise', 1): 4777,
#  ('find', 1): 53172,
#  ('hard', 1): 30622,
#  ('believe', 1): 19843,
#  ('uncountable', 1): 4776,
#  ('coz', 1): 10161,
#  ('unlimited', 1): 4776,
#  ('course', 1): 28465,
#  ('teampositive', 1): 4775,
#  ('https://t.co/SaIX1VpFJF', 1): 4775,
#  ('aldub', 1): 6963,
#  ('☕', 1): 14319,
#  ('rita', 1): 9267,
#  ('info', 1): 34662,
#  ('way', 1): 105989,
#  ('boy', 1): 39379,
#  ('x40', 1): 4769,
#  ('true', 1): 55868,
#  ('https://t.co/N2ORwrOwhD', 1): 4767,
#  ('http://t.co/09GuSuMrNb', 1): 4766,
#  ('sethi', 1): 8336,
#  ('high', 1): 17422,
#  ('exe', 1): 4764,
#  ('skeem', 1): 4764,
#  ('saam', 1): 4764,
#  ('people', 1): 126363,
#  ('http://t.co/iDdtACkA4K', 1): 4763,
#  ('polite', 1): 8671,
#  ('izzat', 1): 4761,
#  ('wese', 1): 4761,
#  ('trust', 1): 20533,
#  ('khawateen', 1): 4761,
#  ('k', 1): 27747,
#  ('sath', 1): 6441,
#  ('mana', 1): 4761,
#  ('kar', 1): 4761,
#  ('deya', 1): 4761,
#  ('evening', 1): 7523,
#  ('sorted', 1): 12901,
#  ('smart', 1): 18753,
#  ('hair', 1): 21059,
#  ('tbh', 1): 17792,
#  ('https://t.co/hJEhDmxuu9', 1): 4757,
#  ('jacob', 1): 5790,
#  ('g', 1): 32530,
#  ('upgrade', 1): 5901,
#  ('tee', 1): 9497,
#  ('family', 1): 42135,
#  ('https://t.co/HL0Fw8msf1', 1): 4754,
#  ('reading', 1): 23984,
#  ('talking', 1): 33526,
#  ('person', 1): 40229,
#  ('two', 1): 48578,
#  ('conversation', 1): 16680,
#  ('online', 1): 12440,
#  ('http://t.co/6rA4ZlpjO9', 1): 4748,
#  ('mclaren', 1): 4746,
#  ('fridayfeeling', 1): 14942,
#  ('tgif', 1): 29590,
#  ('http://t.co/LshgwcXsSv', 1): 4746,
#  ('square', 1): 4744,
#  ('enix', 1): 4744,
#  ('bissmillah', 1): 4744,
#  ('ya', 1): 56701,
#  ('allah', 1): 10358,
#  ('training', 1): 8988,
#  ('socent', 1): 4743,
#  ('startup', 1): 5900,
#  ('drop', 1): 29443,
#  ('youre', 1): 11470,
#  ('arnd', 1): 4743,
#  ('town', 1): 12078,
#  ('basically', 1): 9117,
#  ('piss', 1): 9517,
#  ('cup', 1): 8900,
#  ('test', 1): 17090,
#  ('also', 1): 81168,
#  ('terrible', 1): 7118,
#  ('complicated', 1): 4740,
#  ('discussion', 1): 4740,
#  ('snapchat', 1): 82103,
#  ('lynettelowe', 1): 4739,
#  ('kikmenow', 1): 9261,
#  ('snapme', 1): 4876,
#  ('hot', 1): 59778,
#  ('amazon', 1): 4739,
#  ('kikmeguys', 1): 7892,
#  ('http://t.co/kd54m2IAm6', 1): 4739,
#  ('shift', 1): 10916,
#  ('definately', 1): 4737,
#  ('growing', 1): 13661,
#  ('sport', 1): 10058,
#  ('rt', 1): 15532,
#  ('rakyat', 1): 4735,
#  ('writing', 1): 15010,
#  ('https://t.co/IMRy2BXuzd', 1): 4735,
#  ('since', 1): 38476,
#  ('mentioned', 1): 10713,
#  ('fly', 1): 12157,
#  ('fishing', 1): 4734,
#  ('getting', 1): 75591,
#  ('follows', 1): 14995,
#  ('promoted', 1): 4734,
#  ('post', 1): 46993,
#  ('cyber', 1): 4734,
#  ('stalked', 1): 4734,
#  ('ourdaughtersourpride', 1): 10815,
#  ('mypapamypride', 1): 8263,
#  ('papa', 1): 4966,
#  ('coach', 1): 6079,
#  ('positive', 1): 11238,
#  ('kha', 1): 4731,
#  ('mention', 1): 40225,
#  ('atleast', 1): 8249,
#  ('x39', 1): 4730,
#  ('mango', 1): 4729,
#  ("lassi's", 1): 4729,
#  ("monty's", 1): 4729,
#  ('marvellous', 1): 4729,
#  ('though', 1): 51313,
#  ('suspect', 1): 6984,
#  ('meant', 1): 9176,
#  ('24', 1): 9368,
#  ('hr', 1): 7689,
#  ('touch', 1): 24394,
#  ('kepler', 1): 12315,
#  ('452b', 1): 15161,
#  ('chalna', 1): 4727,
#  ('hai', 1): 18379,
#  ('thankyou', 1): 37371,
#  ('hazel', 1): 4724,
#  ('food', 1): 27023,
#  ('market', 1): 10862,
#  ('brooklyn', 1): 4724,
#  ('pta', 1): 7764,
#  ('http://t.co/ySQkhNDo2B', 1): 4724,
#  ('awake', 1): 16297,
#  ('okayy', 1): 8465,
#  ('awww', 1): 41576,
#  ('https://t.co/9tSQv2DWVm', 1): 4721,
#  ('ha', 1): 56933,
#  ('surprise', 1): 26987,
#  ('doc', 1): 4720,
#  ('splendid', 1): 4720,
#  ('spam', 1): 4719,
#  ('folder', 1): 4719,
#  ('amount', 1): 4719,
#  ('travel', 1): 39532,
#  ('nigeria', 1): 4719,
#  ('claim', 1): 4719,
#  ('rted', 1): 4718,
#  ('leg', 1): 13520,
#  ('hurt', 1): 15067,
#  ('bad', 1): 42802,
#  ('mine', 1): 31784,
#  ('saturday', 1): 17189,
#  ('thaaanks', 1): 4715,
#  ('puhon', 1): 4715,
#  ('happiness', 1): 40878,
#  ('https://t.co/slOn63OUeS', 1): 4714,
#  ('tnc', 1): 4713,
#  ('prior', 1): 4713,
#  ('notification', 1): 7006,
#  ('used', 1): 27395,
#  ('https://t.co/gYx34VfmkK', 1): 4712,
#  ('probably', 1): 28425,
#  ('funny', 1): 53120,
#  ('2:22', 1): 4712,
#  ('fat', 1): 4711,
#  ('co', 1): 4711,
#  ('ate', 1): 11647,
#  ('yuna', 1): 7614,
#  ('tameside', 1): 4710,
#  ('´', 1): 11288,
#  ('google', 1): 14279,
#  ('account', 1): 45883,
#  ('http://t.co/R8jyDxlQyo', 1): 4707,
#  ('scouser', 1): 4706,
#  ('everything', 1): 34607,
#  ('zoe', 1): 4818,
#  ('mate', 1): 14774,
#  ('literally', 1): 19873,
#  ('sameee', 1): 4704,
#  ('https://t.co/T6ZCo4NxDG', 1): 4704,
#  ('edgar', 1): 4703,
#  ('updating', 1): 10216,
#  ('log', 1): 9962,
#  ('bring', 1): 26637,
#  ('abes', 1): 4701,
#  ('http://t.co/xxlXs6xYwe', 1): 4700,
#  ('meet', 1): 57399,
#  ('x38', 1): 4695,
#  ('sigh', 1): 11839,
#  ('dreamily', 1): 4694,
#  ('pout', 1): 4694,
#  ('eye', 1): 29092,
#  ('quacketyquack', 1): 18154,
#  ('happened', 1): 22957,
#  ('phil', 1): 4691,
#  ('em', 1): 10175,
#  ('del', 1): 4690,
#  ('rodders', 1): 4690,
#  ('else', 1): 25083,
#  ('play', 1): 49498,
#  ('newest', 1): 4689,
#  ('gamejam', 1): 4689,
#  ('http://t.co/8J5voDDHcs', 1): 4689,
#  ('irish', 1): 9376,
#  ('literature', 1): 8253,
#  ('inaccessible', 1): 6075,
#  ('http://t.co/PEjHsORGrk', 1): 4686,
#  ("kareena's", 1): 9370,
#  ('fan', 1): 67402,
#  ('knowing', 1): 9011,
#  ('http://t.co/F8V3McI39e', 1): 4681,
#  ('playing', 1): 50438,
#  ('brain', 1): 32225,
#  ('dot', 1): 26585,
#  ('braindots', 1): 26585,
#  ('http://t.co/cHl12JvuxN', 1): 4680,
#  ...}

# %%
len(freqs)
# Out:
# 21748

# %%
#extraction de features
def extract_features(tweet, freqs):
    tweet_words = traiter_tweet(tweet)
    
    pos = 0
    neg = 0
    
    for word in tweet_words:
        pos += freqs.get((word, 1), 0)
        neg += freqs.get((word, 0), 0)
        
    return [1, pos, neg]

# %%
#Création de la matrice BoW
test = extract_features(tweet, freqs)
print(test)
# Out:
# [1, 84709522292, 234081764394]

# %%
#X et y pour entraînement du modele
X = np.array([extract_features(tweet, freqs) for tweet in tweets])
y = np.array(labels)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
tweet_test = "I am comming"

# %%
features_test = np.array([extract_features(tweet_test, freqs)])

# %%
prediction = model.predict(features_test)

# %%
proba = model.predict_proba(features_test)

# %%
print("Sentiment :", "Positif" if prediction[0] == 1 else "Négatif")
print("Probabilité :", proba)
# Out:
# Sentiment : Négatif
# Probabilité : [[0.97776226 0.02223774]]
